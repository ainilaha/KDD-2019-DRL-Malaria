# %% [markdown]
# # [KDD Cup|Humanities Track Tutorial Q-Learning](https://compete.hexagon-ml.com/tutorial/kdd-cuphumanities-track-tutorial/)

# %% [markdown]
# ### KDD Cup|Humanities Track Tutorial Q-Learning
# This Tutorial builds on the previous tutorial to demonstrate a baseline implementation of a standard Reinforcement Learning (RL) Algorithm

# %% [markdown]
# ### State
#
# $S \in \{1,2,3,4,5\}$

# %% [markdown]
# ### Action
# $A_S = [a_{ITN},a_{IRS}]$
#
# where  $a_{ITN} \in [0,1]$ and $a_{IRS} \in [0,1]$

# %% [markdown]
# ### Reward
# $R_{\pi} \in (- \infty,\infty)$
#
# ![](image/rewards2.png)

# %%
import numpy as np
from collections import defaultdict
import random
# !pip3 install git+https://github.com/slremy/netsapi --user --upgrade
from netsapi.challenge import *

# %% [markdown]
# ### Creating a Valid Submission from Agent Code:

# %%
class BanditRPM(object):
    def __init__(self,env):
        self.env = env
        self.action_resolution = 0.1
        self.actions = self.actionSpace()    
        
        self.ActionValue = {}
        self.init = (2,5)
        for key in self.actions:
            self.ActionValue[key] = self.init
        print("self.ActionValue=",self.ActionValue)        
        
    def actionSpace(self):
        x = np.arange(0,1+self.action_resolution,self.action_resolution)
        y = 1-x
        x = x.reshape(len(x),1)
        y = y.reshape(len(y),1)
        xy = np.concatenate((x, y), axis=1)
        xy = [tuple(row) for row in xy]
        
        return xy
    
    def choose_action(self):
        """
        Use Thompson sampling to choose action. Sample from each posterior and choose the max of the samples.
        """
        samples = {}
        print(i)
        for key in self.ActionValue:
            print("key=",key)
#             print("key=",self.ActionValue[key][0])
#             print("self.ActionValue[key][1]=",self.ActionValue[key][1])
            samples[key] = np.random.beta(self.ActionValue[key][0], self.ActionValue[key][1])
            print("samples[key]=",samples[key])
        max_value =  max(samples, key=samples.get)
        print(max_value)
        return max_value    

    def update(self,action,reward):
        """
        Update parameters of posteriors, which are Beta distributions
        """
        a, b = self.ActionValue[action]
        a = a+reward/100
        b = b + 1 - reward/100
        a = 0.001 if a <= 0 else a
        b = 0.001 if b <= 0 else b
        
        self.ActionValue[action] = (a, b)
        
    def train(self):
        for _ in range(20): #Do not change
            self.env.reset()
            while True:
                action =  self.choose_action()
                print("action=",list(action))
                nextstate, reward, done, _ = self.env.evaluateAction(list(action))
                self.update(action,reward)
                if done:
                    break


    def generate(self):
        best_policy = None
        best_reward = -float('Inf'
        self.train()
        best_policy = {state: list(self.choose_action()) for state in range(1,6)}
        best_reward = self.env.evaluatePolicy(best_policy)
        
        print(best_policy, best_reward)
        
        return best_policy, best_reward

# %% [markdown]
# ### Run the EvaluateChallengeSubmission Method with your Agent Class

# %%
EvaluateChallengeSubmission(ChallengeSeqDecEnvironment, BanditRPM, "BanditRPM_submission.csv")
# Out:
# self.ActionValue= {(0.0, 1.0): (2, 5), (0.1, 0.9): (2, 5), (0.2, 0.8): (2, 5), (0.30000000000000004, 0.7): (2, 5), (0.4, 0.6): (2, 5), (0.5, 0.5): (2, 5), (0.6000000000000001, 0.3999999999999999): (2, 5), (0.7000000000000001, 0.29999999999999993): (2, 5), (0.8, 0.19999999999999996): (2, 5), (0.9, 0.09999999999999998): (2, 5), (1.0, 0.0): (2, 5)}
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.24791396764610288
# key= (0.1, 0.9)
# samples[key]= 0.15375726962764952
# key= (0.2, 0.8)
# samples[key]= 0.14558791911483812
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.13250792309228285
# key= (0.4, 0.6)
# samples[key]= 0.15527600050303247
# key= (0.5, 0.5)
# samples[key]= 0.25692874392645926
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2606856103734172
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.030966668433419407
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3784666861583946
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.29622397671592304
# key= (1.0, 0.0)
# samples[key]= 0.10070303888540348
# (0.8, 0.19999999999999996)
# action= [0.8, 0.19999999999999996]
# 105  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.2179994949099482
# key= (0.1, 0.9)
# samples[key]= 0.11147022625371371
# key= (0.2, 0.8)
# samples[key]= 0.21680857842116327
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.18718235803174796
# key= (0.4, 0.6)
# samples[key]= 0.2793248165457074
# key= (0.5, 0.5)
# samples[key]= 0.4959649044919007
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.107864332499917
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.33885478184182
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.06564751208302795
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3501304854557834
# key= (1.0, 0.0)
# samples[key]= 0.4057913623934629
# (0.5, 0.5)
# action= [0.5, 0.5]
# 104  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.1246198472771528
# key= (0.1, 0.9)
# samples[key]= 0.4618181410840176
# key= (0.2, 0.8)
# samples[key]= 0.14114876038043403
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.5219428440241352
# key= (0.4, 0.6)
# samples[key]= 0.08067813476900199
# key= (0.5, 0.5)
# samples[key]= 0.47031521765513884
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.14044419316715975
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.4795169550455519
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.22633707309232182
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.23853606324769444
# key= (1.0, 0.0)
# samples[key]= 0.25987529007526
# (0.30000000000000004, 0.7)
# action= [0.30000000000000004, 0.7]
# 103  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.16902360972166394
# key= (0.1, 0.9)
# samples[key]= 0.1784740180873394
# key= (0.2, 0.8)
# samples[key]= 0.4841306272397517
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.1692019865958865
# key= (0.4, 0.6)
# samples[key]= 0.3680205723159571
# key= (0.5, 0.5)
# samples[key]= 0.485646610614281
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.6777768167548714
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.10166396004345085
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.043065873719177555
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.47261986745989715
# key= (1.0, 0.0)
# samples[key]= 0.08184589983347698
# (0.6000000000000001, 0.3999999999999999)
# action= [0.6000000000000001, 0.3999999999999999]
# 102  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.16196846634229628
# key= (0.1, 0.9)
# samples[key]= 0.13446051416170607
# key= (0.2, 0.8)
# samples[key]= 0.4100205119418821
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.3538751281983789
# key= (0.4, 0.6)
# samples[key]= 0.5300372892353749
# key= (0.5, 0.5)
# samples[key]= 0.5755745223488938
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.358815317475447
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.4908247833704884
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.18817199647052565
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.28789081524589233
# key= (1.0, 0.0)
# samples[key]= 0.08073797391273022
# (0.5, 0.5)
# action= [0.5, 0.5]
# 101  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5449472164768735
# key= (0.1, 0.9)
# samples[key]= 0.18952728007913971
# key= (0.2, 0.8)
# samples[key]= 0.19895111086734651
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.3742294118466756
# key= (0.4, 0.6)
# samples[key]= 0.07974198979315593
# key= (0.5, 0.5)
# samples[key]= 0.1937236499703723
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.46137664707570675
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.32978556225619166
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3548404510405874
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.17856545542265828
# key= (1.0, 0.0)
# samples[key]= 0.333072781703617
# (0.0, 1.0)
# action= [0.0, 1.0]
# 100  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.28137443148711155
# key= (0.1, 0.9)
# samples[key]= 0.299553885193524
# key= (0.2, 0.8)
# samples[key]= 0.4688072026338297
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.3859883076595735
# key= (0.4, 0.6)
# samples[key]= 0.477900075255855
# key= (0.5, 0.5)
# samples[key]= 0.2685977971082214
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.6318674112784374
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1855754313046453
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.5643425395617462
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.5740344444209566
# key= (1.0, 0.0)
# samples[key]= 0.050506311185394344
# (0.6000000000000001, 0.3999999999999999)
# action= [0.6000000000000001, 0.3999999999999999]
# 99  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5684922654676448
# key= (0.1, 0.9)
# samples[key]= 0.16123654907224141
# key= (0.2, 0.8)
# samples[key]= 0.42346069162845035
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.31856687038065634
# key= (0.4, 0.6)
# samples[key]= 0.06592371852339873
# key= (0.5, 0.5)
# samples[key]= 0.1754060092651288
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.18368039609715742
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.31280034637263243
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.38137974784581435
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.11970241713066156
# key= (1.0, 0.0)
# samples[key]= 0.36167452756795404
# (0.0, 1.0)
# action= [0.0, 1.0]
# 98  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.6100993598213348
# key= (0.1, 0.9)
# samples[key]= 0.08461364474057118
# key= (0.2, 0.8)
# samples[key]= 0.12831639707331452
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.12730608436210453
# key= (0.4, 0.6)
# samples[key]= 0.2031442952083756
# key= (0.5, 0.5)
# samples[key]= 0.06663493393776324
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2660799755805921
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.12945376085597632
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.19297653310417162
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.19533611203490575
# key= (1.0, 0.0)
# samples[key]= 0.2925864658805403
# (0.0, 1.0)
# action= [0.0, 1.0]
# 97  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5187821593250752
# key= (0.1, 0.9)
# samples[key]= 0.057066080878173324
# key= (0.2, 0.8)
# samples[key]= 0.30044240940844036
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.4452937611642936
# key= (0.4, 0.6)
# samples[key]= 0.5288053751713846
# key= (0.5, 0.5)
# samples[key]= 0.1723581710906996
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.12730783986247604
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.17531617936091548
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.12400193875674213
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.07370934662123133
# key= (1.0, 0.0)
# samples[key]= 0.18667122760330995
# (0.4, 0.6)
# action= [0.4, 0.6]
# 96  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.43879763983307707
# key= (0.1, 0.9)
# samples[key]= 0.457219180831689
# key= (0.2, 0.8)
# samples[key]= 0.3928709257438074
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.5792898168333597
# key= (0.4, 0.6)
# samples[key]= 0.10759891611645152
# key= (0.5, 0.5)
# samples[key]= 0.12351484613907283
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.08554505612904163
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.15358083663924202
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.23746173137982843
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2795584029320425
# key= (1.0, 0.0)
# samples[key]= 0.3150705595724434
# (0.30000000000000004, 0.7)
# action= [0.30000000000000004, 0.7]
# 95  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.25532376516220984
# key= (0.1, 0.9)
# samples[key]= 0.7009868076312823
# key= (0.2, 0.8)
# samples[key]= 0.23732929806085618
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.03783279788668924
# key= (0.4, 0.6)
# samples[key]= 0.3590705952816539
# key= (0.5, 0.5)
# samples[key]= 0.1555686538122572
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.3312009678090808
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.028366261130286383
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.6635069378111463
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2979398406996261
# key= (1.0, 0.0)
# samples[key]= 0.30091626382524955
# (0.1, 0.9)
# action= [0.1, 0.9]
# 94  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.23817999668284034
# key= (0.1, 0.9)
# samples[key]= 0.1012743995933566
# key= (0.2, 0.8)
# samples[key]= 0.147407332925472
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.11199850216661604
# key= (0.4, 0.6)
# samples[key]= 0.09513749799547294
# key= (0.5, 0.5)
# samples[key]= 0.06253603517252924
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.0727445031797581
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2007503472971161
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.0370351470616462
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.19754328667119272
# key= (1.0, 0.0)
# samples[key]= 0.10368996145291423
# (0.0, 1.0)
# action= [0.0, 1.0]
# 93  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.34162152903001847
# key= (0.1, 0.9)
# samples[key]= 0.11892495739509328
# key= (0.2, 0.8)
# samples[key]= 0.43899084271356975
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.0901937801870836
# key= (0.4, 0.6)
# samples[key]= 0.20259787529924006
# key= (0.5, 0.5)
# samples[key]= 0.14088478244017974
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.3646936898392555
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.028471413125829754
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.0875185957419756
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.6371835745597373
# key= (1.0, 0.0)
# samples[key]= 0.36787336913445445
# (0.9, 0.09999999999999998)
# action= [0.9, 0.09999999999999998]
# 92  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.13873024865538114
# key= (0.1, 0.9)
# samples[key]= 0.25838750583739445
# key= (0.2, 0.8)
# samples[key]= 0.2073872325204175
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.024029336572391893
# key= (0.4, 0.6)
# samples[key]= 0.14737873933404905
# key= (0.5, 0.5)
# samples[key]= 0.2823487318947833
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2938754634063379
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2900619301877822
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.23240136769657416
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4100551139522854
# key= (1.0, 0.0)
# samples[key]= 0.37096085158218783
# (0.9, 0.09999999999999998)
# action= [0.9, 0.09999999999999998]
# 91  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.10538221459847077
# key= (0.1, 0.9)
# samples[key]= 0.4495498396353048
# key= (0.2, 0.8)
# samples[key]= 0.2494294042380345
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.10961936397638625
# key= (0.4, 0.6)
# samples[key]= 0.5111643439612797
# key= (0.5, 0.5)
# samples[key]= 0.3016789286379503
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.5275258005028229
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.18388269621752434
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.576323920835288
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2381662490008633
# key= (1.0, 0.0)
# samples[key]= 0.16424260275493355
# (0.8, 0.19999999999999996)
# action= [0.8, 0.19999999999999996]
# 90  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.41722536999651905
# key= (0.1, 0.9)
# samples[key]= 0.2639424923019047
# key= (0.2, 0.8)
# samples[key]= 0.20852450601800745
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.300961703178888
# key= (0.4, 0.6)
# samples[key]= 0.1218782304953578
# key= (0.5, 0.5)
# samples[key]= 0.05053829157181702
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.18605384334737401
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1015219405828081
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3236065076107258
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4000403169029164
# key= (1.0, 0.0)
# samples[key]= 0.17253230335984746
# (0.0, 1.0)
# action= [0.0, 1.0]
# 89  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4453123849560576
# key= (0.1, 0.9)
# samples[key]= 0.2583584891427362
# key= (0.2, 0.8)
# samples[key]= 0.1735334811103251
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.022449921411823486
# key= (0.4, 0.6)
# samples[key]= 0.17895483240927745
# key= (0.5, 0.5)
# samples[key]= 0.2729853004169202
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.21945909230249103
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.5828586168156978
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.41999921184724603
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4186297082530734
# key= (1.0, 0.0)
# samples[key]= 0.42513806324566733
# (0.7000000000000001, 0.29999999999999993)
# action= [0.7000000000000001, 0.29999999999999993]
# 88  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5849695692055191
# key= (0.1, 0.9)
# samples[key]= 0.2786489006476606
# key= (0.2, 0.8)
# samples[key]= 0.19864878603015576
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.38597580985097785
# key= (0.4, 0.6)
# samples[key]= 0.25057521621852247
# key= (0.5, 0.5)
# samples[key]= 0.10162377470738058
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.015586561888679728
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.0568205119947266
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2936151120724696
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.24630185471795413
# key= (1.0, 0.0)
# samples[key]= 0.07686960463283789
# (0.0, 1.0)
# action= [0.0, 1.0]
# 87  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5075841646597156
# key= (0.1, 0.9)
# samples[key]= 0.03965579221899513
# key= (0.2, 0.8)
# samples[key]= 0.1338743175380691
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.44661381944214984
# key= (0.4, 0.6)
# samples[key]= 0.14084666867061854
# key= (0.5, 0.5)
# samples[key]= 0.3808170517895356
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.12310771907615264
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.6229189430167638
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.5080237210562819
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2959838784178727
# key= (1.0, 0.0)
# samples[key]= 0.2523108692593478
# (0.7000000000000001, 0.29999999999999993)
# action= [0.7000000000000001, 0.29999999999999993]
# 86  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.584352076203843
# key= (0.1, 0.9)
# samples[key]= 0.0495543657327002
# key= (0.2, 0.8)
# samples[key]= 0.24050947930120525
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.2658951811110348
# key= (0.4, 0.6)
# samples[key]= 0.3606874087461971
# key= (0.5, 0.5)
# samples[key]= 0.1596960648047611
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2223365535043608
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2540373555943526
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.11892527410567492
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.15773221468331247
# key= (1.0, 0.0)
# samples[key]= 0.298508351144326
# (0.0, 1.0)
# action= [0.0, 1.0]
# 85  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.42028111760778125
# key= (0.1, 0.9)
# samples[key]= 0.2977451009149007
# key= (0.2, 0.8)
# samples[key]= 0.4435585066398126
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.22582433785860836
# key= (0.4, 0.6)
# samples[key]= 0.05302282852914832
# key= (0.5, 0.5)
# samples[key]= 0.055097568105677716
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.1336918679776292
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.4684689374070762
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2600595405658373
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.40303790161587355
# key= (1.0, 0.0)
# samples[key]= 0.19991275342232362
# (0.7000000000000001, 0.29999999999999993)
# action= [0.7000000000000001, 0.29999999999999993]
# 84  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5644245616925003
# key= (0.1, 0.9)
# samples[key]= 0.30698314602908056
# key= (0.2, 0.8)
# samples[key]= 0.7235758987762984
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.43434229508040256
# key= (0.4, 0.6)
# samples[key]= 0.2879674314998536
# key= (0.5, 0.5)
# samples[key]= 0.09341142371825423
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.16934954728824456
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.28183748924125035
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.14818961534885802
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3399723909712852
# key= (1.0, 0.0)
# samples[key]= 0.3193429384201904
# (0.2, 0.8)
# action= [0.2, 0.8]
# 83  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.798978067894717
# key= (0.1, 0.9)
# samples[key]= 0.43338116529157517
# key= (0.2, 0.8)
# samples[key]= 0.36054526605761594
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.2611193916353701
# key= (0.4, 0.6)
# samples[key]= 0.46198670819134885
# key= (0.5, 0.5)
# samples[key]= 0.12607632414460773
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.1586751759329528
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.5186974395976587
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2835892251935291
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.10909943666518175
# key= (1.0, 0.0)
# samples[key]= 0.24200963732093211
# (0.0, 1.0)
# action= [0.0, 1.0]
# 82  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.25755702076236675
# key= (0.1, 0.9)
# samples[key]= 0.32697408567383734
# key= (0.2, 0.8)
# samples[key]= 0.34552436207879444
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.19516105837186046
# key= (0.4, 0.6)
# samples[key]= 0.1073190423428437
# key= (0.5, 0.5)
# samples[key]= 0.2662393689336141
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.16500681101212306
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.41853628523419495
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.46862816244354627
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.06350247018942233
# key= (1.0, 0.0)
# samples[key]= 0.5138290711885298
# (1.0, 0.0)
# action= [1.0, 0.0]
# 81  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.40713130730102925
# key= (0.1, 0.9)
# samples[key]= 0.4758672728730633
# key= (0.2, 0.8)
# samples[key]= 0.07777532068140203
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.20338906581245678
# key= (0.4, 0.6)
# samples[key]= 0.36646165767272754
# key= (0.5, 0.5)
# samples[key]= 0.32227719408694533
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.08550047874464232
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.4936734862257957
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.13108500735305995
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.31034791490459124
# key= (1.0, 0.0)
# samples[key]= 0.112655673790517
# (0.7000000000000001, 0.29999999999999993)
# action= [0.7000000000000001, 0.29999999999999993]
# 80  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4220098878712722
# key= (0.1, 0.9)
# samples[key]= 0.4387405045392797
# key= (0.2, 0.8)
# samples[key]= 0.21063775149985337
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.2589792767113456
# key= (0.4, 0.6)
# samples[key]= 0.24039453578115458
# key= (0.5, 0.5)
# samples[key]= 0.14175478015040582
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.4665067698375152
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.3552863663784848
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.46015265389143717
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.28879530277218574
# key= (1.0, 0.0)
# samples[key]= 0.4708208899960577
# (1.0, 0.0)
# action= [1.0, 0.0]
# 79  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.45907398983402775
# key= (0.1, 0.9)
# samples[key]= 0.6902584987168953
# key= (0.2, 0.8)
# samples[key]= 0.4337792596023158
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.27473272773975344
# key= (0.4, 0.6)
# samples[key]= 0.26798634478389544
# key= (0.5, 0.5)
# samples[key]= 0.1745478301337457
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.21847538743242872
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.7218189782672207
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.33180605685885173
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.1711040273818473
# key= (1.0, 0.0)
# samples[key]= 0.23343733068723635
# (0.7000000000000001, 0.29999999999999993)
# action= [0.7000000000000001, 0.29999999999999993]
# 78  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4287354986062315
# key= (0.1, 0.9)
# samples[key]= 0.07993103127602591
# key= (0.2, 0.8)
# samples[key]= 0.18901929749550564
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.326539869037147
# key= (0.4, 0.6)
# samples[key]= 0.18935125221853938
# key= (0.5, 0.5)
# samples[key]= 0.2575712499589526
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.26031156032751723
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2861601042157807
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.14023145370260084
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.20147623341836993
# key= (1.0, 0.0)
# samples[key]= 0.3908500156807824
# (0.0, 1.0)
# action= [0.0, 1.0]
# 77  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.32940600174840107
# key= (0.1, 0.9)
# samples[key]= 0.18819538577143183
# key= (0.2, 0.8)
# samples[key]= 0.10986252399042393
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.10870667338686034
# key= (0.4, 0.6)
# samples[key]= 0.3918441609418138
# key= (0.5, 0.5)
# samples[key]= 0.1799080715053902
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2935562567956298
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.13550844058764203
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.12618040535976455
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3700308206289527
# key= (1.0, 0.0)
# samples[key]= 0.19953662095963418
# (0.4, 0.6)
# action= [0.4, 0.6]
# 76  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5431896512024456
# key= (0.1, 0.9)
# samples[key]= 0.49465328473643655
# key= (0.2, 0.8)
# samples[key]= 0.4156535735895677
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.12957570385006165
# key= (0.4, 0.6)
# samples[key]= 0.277231888165722
# key= (0.5, 0.5)
# samples[key]= 0.13077031321910065
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.16467746874181868
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.0957014351266422
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.08371079167846927
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.5131395515801905
# key= (1.0, 0.0)
# samples[key]= 0.2858344793327686
# (0.0, 1.0)
# action= [0.0, 1.0]
# 75  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.538755651801524
# key= (0.1, 0.9)
# samples[key]= 0.31859511556018477
# key= (0.2, 0.8)
# samples[key]= 0.4648059151698506
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.229051332155378
# key= (0.4, 0.6)
# samples[key]= 0.48954215354442543
# key= (0.5, 0.5)
# samples[key]= 0.04731931756445634
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.5456995755527329
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2918706659970025
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.4120817258948469
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.15845033078555387
# key= (1.0, 0.0)
# samples[key]= 0.4878959401265989
# (0.6000000000000001, 0.3999999999999999)
# action= [0.6000000000000001, 0.3999999999999999]
# 74  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5149692337420206
# key= (0.1, 0.9)
# samples[key]= 0.06474807232810227
# key= (0.2, 0.8)
# samples[key]= 0.4085905871879418
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.2664581249395811
# key= (0.4, 0.6)
# samples[key]= 0.2863951769496444
# key= (0.5, 0.5)
# samples[key]= 0.06956642249305421
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.14111362825815518
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.18166199408910227
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3882517007785472
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.1722279617570195
# key= (1.0, 0.0)
# samples[key]= 0.2503926697451517
# (0.0, 1.0)
# action= [0.0, 1.0]
# 73  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4999427685179385
# key= (0.1, 0.9)
# samples[key]= 0.3256967204505291
# key= (0.2, 0.8)
# samples[key]= 0.3070360986561127
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.14367917249071246
# key= (0.4, 0.6)
# samples[key]= 0.18629443166255405
# key= (0.5, 0.5)
# samples[key]= 0.18870117577177598
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.1571861630450115
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2401343036763614
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.4654838882055878
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4246241438227473
# key= (1.0, 0.0)
# samples[key]= 0.3621108425040712
# (0.0, 1.0)
# action= [0.0, 1.0]
# 72  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.42243337400921566
# key= (0.1, 0.9)
# samples[key]= 0.2721918833086624
# key= (0.2, 0.8)
# samples[key]= 0.07567980760219126
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.13653416664824738
# key= (0.4, 0.6)
# samples[key]= 0.019199930467335116
# key= (0.5, 0.5)
# samples[key]= 0.26686108592783464
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.062339861387106996
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.3939659133815787
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3114348322886676
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.10342557430170969
# key= (1.0, 0.0)
# samples[key]= 0.13640025184110327
# (0.0, 1.0)
# action= [0.0, 1.0]
# 71  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.40041514135061307
# key= (0.1, 0.9)
# samples[key]= 0.5812932782043708
# key= (0.2, 0.8)
# samples[key]= 0.6683576848399027
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.27721523914713675
# key= (0.4, 0.6)
# samples[key]= 0.16598904741342982
# key= (0.5, 0.5)
# samples[key]= 0.2829317134639972
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.07448154565932864
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.3673746696417263
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.4654172815439028
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2112709710380419
# key= (1.0, 0.0)
# samples[key]= 0.1977855101323881
# (0.2, 0.8)
# action= [0.2, 0.8]
# 70  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5393556715386599
# key= (0.1, 0.9)
# samples[key]= 0.11039683276603371
# key= (0.2, 0.8)
# samples[key]= 0.3562744048023876
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.2700948030952506
# key= (0.4, 0.6)
# samples[key]= 0.1527921860253837
# key= (0.5, 0.5)
# samples[key]= 0.3582563469271449
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.27364536001094353
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.17956710182766444
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.49103599923671937
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.5074945589120619
# key= (1.0, 0.0)
# samples[key]= 0.3947187268244622
# (0.0, 1.0)
# action= [0.0, 1.0]
# 69  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4073559506285437
# key= (0.1, 0.9)
# samples[key]= 0.44964684978847774
# key= (0.2, 0.8)
# samples[key]= 0.325836363928577
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.11303620612501254
# key= (0.4, 0.6)
# samples[key]= 0.11078696124110299
# key= (0.5, 0.5)
# samples[key]= 0.17112720856653074
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.02764998137807524
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.22865147524141183
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3834108989822419
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.12661287994403717
# key= (1.0, 0.0)
# samples[key]= 0.38134449266042836
# (0.1, 0.9)
# action= [0.1, 0.9]
# 68  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5047129538598599
# key= (0.1, 0.9)
# samples[key]= 0.13162978563628966
# key= (0.2, 0.8)
# samples[key]= 0.1351532970150358
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.13590392362138462
# key= (0.4, 0.6)
# samples[key]= 0.12618018078196583
# key= (0.5, 0.5)
# samples[key]= 0.15811476467601182
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.34814374115520247
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.42272865886199856
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.07678458537192463
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2517463271981323
# key= (1.0, 0.0)
# samples[key]= 0.3037122219857465
# (0.0, 1.0)
# action= [0.0, 1.0]
# 67  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.6846737635106598
# key= (0.1, 0.9)
# samples[key]= 0.1676025732773369
# key= (0.2, 0.8)
# samples[key]= 0.30594833491010137
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.14012998325661874
# key= (0.4, 0.6)
# samples[key]= 0.08923983669408808
# key= (0.5, 0.5)
# samples[key]= 0.5042379093465428
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2846929023857261
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.30669037756214057
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.24713428281786026
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.5015256173276635
# key= (1.0, 0.0)
# samples[key]= 0.09862634347443737
# (0.0, 1.0)
# action= [0.0, 1.0]
# 66  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3435771643635628
# key= (0.1, 0.9)
# samples[key]= 0.22518169438599842
# key= (0.2, 0.8)
# samples[key]= 0.13298873863069846
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.0296249082417734
# key= (0.4, 0.6)
# samples[key]= 0.10402958398239362
# key= (0.5, 0.5)
# samples[key]= 0.4129483327719015
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.20982742376907365
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.24455128296775455
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.258535594105671
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3680930265570874
# key= (1.0, 0.0)
# samples[key]= 0.09054675249322885
# (0.5, 0.5)
# action= [0.5, 0.5]
# 65  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.28810257507300374
# key= (0.1, 0.9)
# samples[key]= 0.04773914155405973
# key= (0.2, 0.8)
# samples[key]= 0.1443428449687981
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.18347358739025324
# key= (0.4, 0.6)
# samples[key]= 0.14447484788223713
# key= (0.5, 0.5)
# samples[key]= 0.17416829911975423
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.29518596856899326
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.6615966247912097
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.23953180050804668
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2546842959375541
# key= (1.0, 0.0)
# samples[key]= 0.1297428434419342
# (0.7000000000000001, 0.29999999999999993)
# action= [0.7000000000000001, 0.29999999999999993]
# 64  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.42038069540639217
# key= (0.1, 0.9)
# samples[key]= 0.2094503401700385
# key= (0.2, 0.8)
# samples[key]= 0.26466588866906177
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.07582755917813869
# key= (0.4, 0.6)
# samples[key]= 0.037899520157649386
# key= (0.5, 0.5)
# samples[key]= 0.09020204877683276
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.37582730197500674
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.30016510834455346
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.16954630308121188
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.5046576427693777
# key= (1.0, 0.0)
# samples[key]= 0.44311468193289777
# (0.9, 0.09999999999999998)
# action= [0.9, 0.09999999999999998]
# 63  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4875708439078661
# key= (0.1, 0.9)
# samples[key]= 0.15614799271108518
# key= (0.2, 0.8)
# samples[key]= 0.3541926324180771
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.5826444524277695
# key= (0.4, 0.6)
# samples[key]= 0.2087575038668873
# key= (0.5, 0.5)
# samples[key]= 0.15539290918680626
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.16652685956677063
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.16488876275222664
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.48541286971432446
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2232789582242121
# key= (1.0, 0.0)
# samples[key]= 0.24166663921699044
# (0.30000000000000004, 0.7)
# action= [0.30000000000000004, 0.7]
# 62  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3380534810643735
# key= (0.1, 0.9)
# samples[key]= 0.30344326030954355
# key= (0.2, 0.8)
# samples[key]= 0.11737332168297761
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.21219541989734525
# key= (0.4, 0.6)
# samples[key]= 0.2794726281864373
# key= (0.5, 0.5)
# samples[key]= 0.15239470435474411
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.4638137829719041
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.10701154020141544
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.32621717467247185
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.23304862396071357
# key= (1.0, 0.0)
# samples[key]= 0.08536515129552119
# (0.6000000000000001, 0.3999999999999999)
# action= [0.6000000000000001, 0.3999999999999999]
# 61  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.2761562329970584
# key= (0.1, 0.9)
# samples[key]= 0.36410435648109263
# key= (0.2, 0.8)
# samples[key]= 0.39891325966331714
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.10515353376747082
# key= (0.4, 0.6)
# samples[key]= 0.5584323944507444
# key= (0.5, 0.5)
# samples[key]= 0.2600737465579342
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.1552944795390149
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1116703746885745
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2815021485749055
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.21546469174678384
# key= (1.0, 0.0)
# samples[key]= 0.39988009729176494
# (0.4, 0.6)
# action= [0.4, 0.6]
# 60  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.47730801259946015
# key= (0.1, 0.9)
# samples[key]= 0.15197793155631933
# key= (0.2, 0.8)
# samples[key]= 0.09203471130580167
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.09364093656165244
# key= (0.4, 0.6)
# samples[key]= 0.17842149391025341
# key= (0.5, 0.5)
# samples[key]= 0.13249312279974648
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.041409323966943294
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2169956852189532
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.5349282602866151
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.12021697603012817
# key= (1.0, 0.0)
# samples[key]= 0.15263144012102192
# (0.8, 0.19999999999999996)
# action= [0.8, 0.19999999999999996]
# 59  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5504869654050857
# key= (0.1, 0.9)
# samples[key]= 0.16009389806262636
# key= (0.2, 0.8)
# samples[key]= 0.2549164268723986
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.12199418554175856
# key= (0.4, 0.6)
# samples[key]= 0.13998175142871416
# key= (0.5, 0.5)
# samples[key]= 0.3733199540315959
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.1418939105775039
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.26976660240570477
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.22476880635228344
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.2903652129460814
# key= (1.0, 0.0)
# samples[key]= 0.4964431627002152
# (0.0, 1.0)
# action= [0.0, 1.0]
# 58  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5637315340109114
# key= (0.1, 0.9)
# samples[key]= 0.436922037550031
# key= (0.2, 0.8)
# samples[key]= 0.4014139368692694
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.09435796373114792
# key= (0.4, 0.6)
# samples[key]= 0.24970265068292888
# key= (0.5, 0.5)
# samples[key]= 0.033379512902625356
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.026401747680426517
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1625046032657177
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.127150667438654
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.06510669975853146
# key= (1.0, 0.0)
# samples[key]= 0.23339311334766227
# (0.0, 1.0)
# action= [0.0, 1.0]
# 57  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.36576266883958297
# key= (0.1, 0.9)
# samples[key]= 0.1400249979001062
# key= (0.2, 0.8)
# samples[key]= 0.021679425491606407
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.032363068279291723
# key= (0.4, 0.6)
# samples[key]= 0.18416673896572694
# key= (0.5, 0.5)
# samples[key]= 0.06963751544555909
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.44802648342531154
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.21793521911335495
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.08051531365483498
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.17577313194758326
# key= (1.0, 0.0)
# samples[key]= 0.11090786910319385
# (0.6000000000000001, 0.3999999999999999)
# action= [0.6000000000000001, 0.3999999999999999]
# 56  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3619757380095515
# key= (0.1, 0.9)
# samples[key]= 0.2404474323542744
# key= (0.2, 0.8)
# samples[key]= 0.4108997218769226
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.20346306661841163
# key= (0.4, 0.6)
# samples[key]= 0.05415232143022561
# key= (0.5, 0.5)
# samples[key]= 0.25368696850154854
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.11236976353046689
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2194868905787921
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.010468838211243864
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.14968683537010172
# key= (1.0, 0.0)
# samples[key]= 0.44326697951728955
# (1.0, 0.0)
# action= [1.0, 0.0]
# 55  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5777476404071014
# key= (0.1, 0.9)
# samples[key]= 0.1771824200687774
# key= (0.2, 0.8)
# samples[key]= 0.17879152161355785
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.30745348484399154
# key= (0.4, 0.6)
# samples[key]= 0.27512409307382285
# key= (0.5, 0.5)
# samples[key]= 0.17079311460438248
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.22511074808093579
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.11296497470776883
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.18870418052022817
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.19471550982642669
# key= (1.0, 0.0)
# samples[key]= 0.4991881842858851
# (0.0, 1.0)
# action= [0.0, 1.0]
# 54  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.6421189075952184
# key= (0.1, 0.9)
# samples[key]= 0.3224434577349921
# key= (0.2, 0.8)
# samples[key]= 0.2209185571753591
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.15943170925150577
# key= (0.4, 0.6)
# samples[key]= 0.17429994472138513
# key= (0.5, 0.5)
# samples[key]= 0.20021829294744758
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.09529937379494795
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.06978716176246756
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.27957438449001365
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.18988569204783726
# key= (1.0, 0.0)
# samples[key]= 0.6325690219986868
# (0.0, 1.0)
# action= [0.0, 1.0]
# 53  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5543582323576254
# key= (0.1, 0.9)
# samples[key]= 0.20406926380459692
# key= (0.2, 0.8)
# samples[key]= 0.13311189709164883
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.12333886557896849
# key= (0.4, 0.6)
# samples[key]= 0.06519730451481362
# key= (0.5, 0.5)
# samples[key]= 0.31564584736092394
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.32151792607828833
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.3803303446674586
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.16234810030446264
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.24207518239102174
# key= (1.0, 0.0)
# samples[key]= 0.29560652011869865
# (0.0, 1.0)
# action= [0.0, 1.0]
# 52  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4528680042048199
# key= (0.1, 0.9)
# samples[key]= 0.07152770961491828
# key= (0.2, 0.8)
# samples[key]= 0.06353418588020132
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.4336518320706131
# key= (0.4, 0.6)
# samples[key]= 0.04231829908573546
# key= (0.5, 0.5)
# samples[key]= 0.021212064503433447
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.15243825853559625
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.213153385910071
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.04702669633907202
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.14980380374043503
# key= (1.0, 0.0)
# samples[key]= 0.4353425963188237
# (0.0, 1.0)
# action= [0.0, 1.0]
# 51  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3884328506960834
# key= (0.1, 0.9)
# samples[key]= 0.28964515247558853
# key= (0.2, 0.8)
# samples[key]= 0.24884509146696993
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.22171149009050842
# key= (0.4, 0.6)
# samples[key]= 0.15013858943196548
# key= (0.5, 0.5)
# samples[key]= 0.22905642480160593
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.10302826643612886
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.12097874342475701
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.40506098000242596
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4253976128512691
# key= (1.0, 0.0)
# samples[key]= 0.07627387926571325
# (0.9, 0.09999999999999998)
# action= [0.9, 0.09999999999999998]
# 50  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5235673323485269
# key= (0.1, 0.9)
# samples[key]= 0.22342915833928592
# key= (0.2, 0.8)
# samples[key]= 0.2549797832991922
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.29212529479340715
# key= (0.4, 0.6)
# samples[key]= 0.4607596557214852
# key= (0.5, 0.5)
# samples[key]= 0.19607930617128252
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.34749158120886214
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.2504721589481285
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2601786571482178
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.16085116297837151
# key= (1.0, 0.0)
# samples[key]= 0.5057914692332693
# (0.0, 1.0)
# action= [0.0, 1.0]
# 49  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4092205939155426
# key= (0.1, 0.9)
# samples[key]= 0.04799567806394145
# key= (0.2, 0.8)
# samples[key]= 0.26091165067800876
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.09637563207925608
# key= (0.4, 0.6)
# samples[key]= 0.09914524987880932
# key= (0.5, 0.5)
# samples[key]= 0.22984745513439078
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.21662491157621072
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.21813993740939777
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.39208085897717765
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.14925519925313072
# key= (1.0, 0.0)
# samples[key]= 0.2956902882430351
# (0.0, 1.0)
# action= [0.0, 1.0]
# 48  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4394171797971293
# key= (0.1, 0.9)
# samples[key]= 0.2660468682716079
# key= (0.2, 0.8)
# samples[key]= 0.41456737182588915
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.15074164691984274
# key= (0.4, 0.6)
# samples[key]= 0.15434029280859596
# key= (0.5, 0.5)
# samples[key]= 0.12878155531698773
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.07345858720579851
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1914224431989606
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.36853288344973145
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.30172961269340814
# key= (1.0, 0.0)
# samples[key]= 0.4835972591251031
# (1.0, 0.0)
# action= [1.0, 0.0]
# 47  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3417274991057407
# key= (0.1, 0.9)
# samples[key]= 0.11144530309396147
# key= (0.2, 0.8)
# samples[key]= 0.3186364930557621
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.03698344520179876
# key= (0.4, 0.6)
# samples[key]= 0.04325704776417518
# key= (0.5, 0.5)
# samples[key]= 0.20244924046025242
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2300128787965199
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.31304877061030595
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2819538090945377
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.14681627054799426
# key= (1.0, 0.0)
# samples[key]= 0.37846117285682457
# (1.0, 0.0)
# action= [1.0, 0.0]
# 46  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4736239279214296
# key= (0.1, 0.9)
# samples[key]= 0.15867760169828413
# key= (0.2, 0.8)
# samples[key]= 0.15311394630711808
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.3724554675001484
# key= (0.4, 0.6)
# samples[key]= 0.13498223591408612
# key= (0.5, 0.5)
# samples[key]= 0.2561071715144154
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.4577654516525129
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.37339661229365434
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.03758598871268789
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3561394373971936
# key= (1.0, 0.0)
# samples[key]= 0.5164490450975194
# (1.0, 0.0)
# action= [1.0, 0.0]
# 45  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.32553735861145194
# key= (0.1, 0.9)
# samples[key]= 0.3483280979250437
# key= (0.2, 0.8)
# samples[key]= 0.12862028278045184
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.2385249938187024
# key= (0.4, 0.6)
# samples[key]= 0.06330647744309977
# key= (0.5, 0.5)
# samples[key]= 0.30888358454855597
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.4533522134087826
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.05659934483035867
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.16020549358298633
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.22224938258308838
# key= (1.0, 0.0)
# samples[key]= 0.5325832873953592
# (1.0, 0.0)
# action= [1.0, 0.0]
# 44  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5595386104392646
# key= (0.1, 0.9)
# samples[key]= 0.3861436746564947
# key= (0.2, 0.8)
# samples[key]= 0.07509300373281376
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.23446767277171188
# key= (0.4, 0.6)
# samples[key]= 0.46295008869425486
# key= (0.5, 0.5)
# samples[key]= 0.16668697272730607
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.3836096228098837
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.106396628160638
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.4227946994621092
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.47427869663615513
# key= (1.0, 0.0)
# samples[key]= 0.28142994580610264
# (0.0, 1.0)
# action= [0.0, 1.0]
# 43  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.402193501962676
# key= (0.1, 0.9)
# samples[key]= 0.21277530866828778
# key= (0.2, 0.8)
# samples[key]= 0.31116011852112235
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.5580166976062112
# key= (0.4, 0.6)
# samples[key]= 0.3187267703190559
# key= (0.5, 0.5)
# samples[key]= 0.0965882412723931
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.1128324116111061
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.06608342336770394
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3781328291922945
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4272531898265262
# key= (1.0, 0.0)
# samples[key]= 0.4592419239186774
# (0.30000000000000004, 0.7)
# action= [0.30000000000000004, 0.7]
# 42  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3789597647451622
# key= (0.1, 0.9)
# samples[key]= 0.07615779254929164
# key= (0.2, 0.8)
# samples[key]= 0.38799939436035685
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.12598397824630983
# key= (0.4, 0.6)
# samples[key]= 0.2661803705451876
# key= (0.5, 0.5)
# samples[key]= 0.28189663346507016
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.3762323985368601
# key= (0.7000000000000001, 0.29999999999999993)
# ...
# key= (0.1, 0.9)
# samples[key]= 0.12247184637121587
# key= (0.2, 0.8)
# samples[key]= 0.2574476551274739
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.05264708978351524
# key= (0.4, 0.6)
# samples[key]= 0.529982506953545
# key= (0.5, 0.5)
# samples[key]= 0.42912226294606276
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.14303116744632402
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.056550648567109306
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2048995085205953
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.33682516585524286
# key= (1.0, 0.0)
# samples[key]= 0.44663735592344855
# (0.4, 0.6)
# action= [0.4, 0.6]
# 84  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4178660957120855
# key= (0.1, 0.9)
# samples[key]= 0.45888643457584033
# key= (0.2, 0.8)
# samples[key]= 0.12563774417707432
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.23957573121995143
# key= (0.4, 0.6)
# samples[key]= 0.3710051551932274
# key= (0.5, 0.5)
# samples[key]= 0.09964994196717847
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.16937732627230798
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.22892829490187291
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.0716272992302124
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.28683376606711786
# key= (1.0, 0.0)
# samples[key]= 0.5382825510482493
# (1.0, 0.0)
# action= [1.0, 0.0]
# 83  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.15598034111305492
# key= (0.1, 0.9)
# samples[key]= 0.2198047870439194
# key= (0.2, 0.8)
# samples[key]= 0.1881598109487209
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.3756854478968397
# key= (0.4, 0.6)
# samples[key]= 0.301252269470176
# key= (0.5, 0.5)
# samples[key]= 0.25784106043636346
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2771882780905324
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.21840298212311113
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.24309600925967947
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.1730981422049398
# key= (1.0, 0.0)
# samples[key]= 0.35073551044351964
# (0.30000000000000004, 0.7)
# action= [0.30000000000000004, 0.7]
# 82  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.09742764349942909
# key= (0.1, 0.9)
# samples[key]= 0.34521185078905164
# key= (0.2, 0.8)
# samples[key]= 0.5628973500680335
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.13460880174395384
# key= (0.4, 0.6)
# samples[key]= 0.2211968272729923
# key= (0.5, 0.5)
# samples[key]= 0.24610386663506092
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.40863992603377663
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.16808566038246206
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.28589599101865165
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4354475725226103
# key= (1.0, 0.0)
# samples[key]= 0.4557361042591768
# (0.2, 0.8)
# action= [0.2, 0.8]
# 81  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.24893400381070804
# key= (0.1, 0.9)
# samples[key]= 0.2800071646063052
# key= (0.2, 0.8)
# samples[key]= 0.1908435942132865
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.5010008295661906
# key= (0.4, 0.6)
# samples[key]= 0.2200919251117019
# key= (0.5, 0.5)
# samples[key]= 0.06890724609299834
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.3315644009688397
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1430521269101936
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.4400590508170441
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.21001830622800902
# key= (1.0, 0.0)
# samples[key]= 0.22323680494168144
# (0.30000000000000004, 0.7)
# action= [0.30000000000000004, 0.7]
# 80  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.6048641427761418
# key= (0.1, 0.9)
# samples[key]= 0.34315089001580407
# key= (0.2, 0.8)
# samples[key]= 0.5122220024431704
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.17344422856565148
# key= (0.4, 0.6)
# samples[key]= 0.35778276733193043
# key= (0.5, 0.5)
# samples[key]= 0.1890930798648124
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.08184440883566332
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.1351373029490778
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.22564112191769226
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.4316264586484923
# key= (1.0, 0.0)
# samples[key]= 0.40974556760874814
# (0.0, 1.0)
# action= [0.0, 1.0]
# 79  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.25829381453371075
# key= (0.1, 0.9)
# samples[key]= 0.16602073798992692
# key= (0.2, 0.8)
# samples[key]= 0.20770681425004622
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.10447037991954791
# key= (0.4, 0.6)
# samples[key]= 0.2001238080035263
# key= (0.5, 0.5)
# samples[key]= 0.22582379952449455
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.17057403315439987
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.31169550495352394
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.28498017099453216
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.24559158992375638
# key= (1.0, 0.0)
# samples[key]= 0.4183439295120494
# (1.0, 0.0)
# action= [1.0, 0.0]
# 78  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3164809111706196
# key= (0.1, 0.9)
# samples[key]= 0.2663926797685207
# key= (0.2, 0.8)
# samples[key]= 0.1882471251162816
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.08015184445322573
# key= (0.4, 0.6)
# samples[key]= 0.078950193578975
# key= (0.5, 0.5)
# samples[key]= 0.2252628045831107
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.31704993840983536
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.07534824216291756
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.32901741342487206
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3010578458376663
# key= (1.0, 0.0)
# samples[key]= 0.3420357381841316
# (1.0, 0.0)
# action= [1.0, 0.0]
# 77  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3757875609060788
# key= (0.1, 0.9)
# samples[key]= 0.18497007124575218
# key= (0.2, 0.8)
# samples[key]= 0.13876048601347712
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.26621819396778984
# key= (0.4, 0.6)
# samples[key]= 0.2716656666975346
# key= (0.5, 0.5)
# samples[key]= 0.24791856594359843
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.17795415488569452
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.16833067811729607
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.0934425603071683
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.14478397488995154
# key= (1.0, 0.0)
# samples[key]= 0.5921596080850212
# (1.0, 0.0)
# action= [1.0, 0.0]
# 76  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.42767150543535376
# key= (0.1, 0.9)
# samples[key]= 0.32370810958691426
# key= (0.2, 0.8)
# samples[key]= 0.1623099927793311
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.07372182072068553
# key= (0.4, 0.6)
# samples[key]= 0.17544141678696765
# key= (0.5, 0.5)
# samples[key]= 0.3350281040677518
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.15261072984607454
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.12992138998896718
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.05984977063411444
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.41735877425469686
# key= (1.0, 0.0)
# samples[key]= 0.45184089250663234
# (1.0, 0.0)
# action= [1.0, 0.0]
# 75  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.28831391833514
# key= (0.1, 0.9)
# samples[key]= 0.37498326552685424
# key= (0.2, 0.8)
# samples[key]= 0.41736241421238407
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.1989270011032477
# key= (0.4, 0.6)
# samples[key]= 0.4861841658085056
# key= (0.5, 0.5)
# samples[key]= 0.15596813592773368
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2782666426944457
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.12453109153670719
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.08447936161151393
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.29487804166386616
# key= (1.0, 0.0)
# samples[key]= 0.4907119418768213
# (1.0, 0.0)
# action= [1.0, 0.0]
# 74  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.19089420434945487
# key= (0.1, 0.9)
# samples[key]= 0.25758456491131004
# key= (0.2, 0.8)
# samples[key]= 0.17418410660274614
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.19638462195873843
# key= (0.4, 0.6)
# samples[key]= 0.3570155165078602
# key= (0.5, 0.5)
# samples[key]= 0.3294156180837364
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.5378869857926982
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.15217360195322766
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3442399861064158
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.38537128555308664
# key= (1.0, 0.0)
# samples[key]= 0.20068962533483742
# (0.6000000000000001, 0.3999999999999999)
# action= [0.6000000000000001, 0.3999999999999999]
# 73  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4154621493307094
# key= (0.1, 0.9)
# samples[key]= 0.5072260872192103
# key= (0.2, 0.8)
# samples[key]= 0.3416315706802762
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.20647313150789612
# key= (0.4, 0.6)
# samples[key]= 0.1260972147695418
# key= (0.5, 0.5)
# samples[key]= 0.13948784467409187
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.4051956280364955
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.08069346502068465
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.08065830388268938
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.06872914176321704
# key= (1.0, 0.0)
# samples[key]= 0.2918874143087247
# (0.1, 0.9)
# action= [0.1, 0.9]
# 72  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.2962754487445737
# key= (0.1, 0.9)
# samples[key]= 0.4795153089978689
# key= (0.2, 0.8)
# samples[key]= 0.085296374095171
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.1542231363666256
# key= (0.4, 0.6)
# samples[key]= 0.2591875072896268
# key= (0.5, 0.5)
# samples[key]= 0.3199848001556782
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.2852771355133349
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.04687978608110284
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.2827425598153776
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.48658721196853266
# key= (1.0, 0.0)
# samples[key]= 0.46368443438731927
# (0.9, 0.09999999999999998)
# action= [0.9, 0.09999999999999998]
# 71  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.08074941358549344
# key= (0.1, 0.9)
# samples[key]= 0.21159164786109708
# key= (0.2, 0.8)
# samples[key]= 0.32427239853762035
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.1627583112133874
# key= (0.4, 0.6)
# samples[key]= 0.08501169252854326
# key= (0.5, 0.5)
# samples[key]= 0.3583677365631337
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.13626241945724532
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.256397961637779
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.1948523715283096
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.31320474999867465
# key= (1.0, 0.0)
# samples[key]= 0.12070730349330942
# (0.5, 0.5)
# action= [0.5, 0.5]
# 70  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4996308427543967
# key= (0.1, 0.9)
# samples[key]= 0.3367553279422984
# key= (0.2, 0.8)
# samples[key]= 0.430214744283648
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.43851629337478504
# key= (0.4, 0.6)
# samples[key]= 0.16836130454747023
# key= (0.5, 0.5)
# samples[key]= 0.22827880708404744
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.03163016462777137
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.28181227229412553
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.15022074721657472
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.34101613708458783
# key= (1.0, 0.0)
# samples[key]= 0.4733094260559924
# (0.0, 1.0)
# action= [0.0, 1.0]
# 69  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.3182473165804951
# key= (0.1, 0.9)
# samples[key]= 0.3178532634705483
# key= (0.2, 0.8)
# samples[key]= 0.2422366331735815
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.09149087170079054
# key= (0.4, 0.6)
# samples[key]= 0.1314023727985572
# key= (0.5, 0.5)
# samples[key]= 0.15476344771485176
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.04475807362822318
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.12423049668254044
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.07569711679221545
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3210821394762778
# key= (1.0, 0.0)
# samples[key]= 0.396805388473622
# (1.0, 0.0)
# action= [1.0, 0.0]
# 68  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.20959153779380454
# key= (0.1, 0.9)
# samples[key]= 0.5148064315487567
# key= (0.2, 0.8)
# samples[key]= 0.14322694538684197
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.07567796070949738
# key= (0.4, 0.6)
# samples[key]= 0.24263725325467425
# key= (0.5, 0.5)
# samples[key]= 0.3151452924350258
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.06150691259075709
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.38498818613841373
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.3671920865841431
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.42820259225978935
# key= (1.0, 0.0)
# samples[key]= 0.44228447285718064
# (0.1, 0.9)
# action= [0.1, 0.9]
# 67  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.5383933654590732
# key= (0.1, 0.9)
# samples[key]= 0.5590352930227115
# key= (0.2, 0.8)
# samples[key]= 0.1158698459925011
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.07576531435811049
# key= (0.4, 0.6)
# samples[key]= 0.1707373614059617
# key= (0.5, 0.5)
# samples[key]= 0.22168206709511068
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.21721021976751817
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.05159027006499236
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.28887097348853896
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.34183188531023606
# key= (1.0, 0.0)
# samples[key]= 0.3317237796842373
# (0.1, 0.9)
# action= [0.1, 0.9]
# 66  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4801476074787913
# key= (0.1, 0.9)
# samples[key]= 0.27204772002344346
# key= (0.2, 0.8)
# samples[key]= 0.24201755353303195
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.0025661135124417076
# key= (0.4, 0.6)
# samples[key]= 0.1968179114745299
# key= (0.5, 0.5)
# samples[key]= 0.2252778642121016
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.04612345622023235
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.27786633091062957
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.01094678197810025
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.23943972802268168
# key= (1.0, 0.0)
# samples[key]= 0.24455917562542245
# (0.0, 1.0)
# action= [0.0, 1.0]
# 65  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.4942428164067131
# key= (0.1, 0.9)
# samples[key]= 0.24649788153411636
# key= (0.2, 0.8)
# samples[key]= 0.18956880742647345
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.14877851888035673
# key= (0.4, 0.6)
# samples[key]= 0.07974329112818195
# key= (0.5, 0.5)
# samples[key]= 0.36148926720644253
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.4121176046396567
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.13011082915258199
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.331727102082878
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.3063273261712487
# key= (1.0, 0.0)
# samples[key]= 0.5556330144457166
# (1.0, 0.0)
# action= [1.0, 0.0]
# 64  Evaluations Remaining
# [1.0, 0.0]
# key= (0.0, 1.0)
# samples[key]= 0.20714355192195916
# key= (0.1, 0.9)
# samples[key]= 0.5130211994229414
# key= (0.2, 0.8)
# samples[key]= 0.2807712151818586
# key= (0.30000000000000004, 0.7)
# samples[key]= 0.157088001447135
# key= (0.4, 0.6)
# samples[key]= 0.23450338861802664
# key= (0.5, 0.5)
# samples[key]= 0.06927526745157735
# key= (0.6000000000000001, 0.3999999999999999)
# samples[key]= 0.11500333356465041
# key= (0.7000000000000001, 0.29999999999999993)
# samples[key]= 0.026408366267284517
# key= (0.8, 0.19999999999999996)
# samples[key]= 0.6893729003355056
# key= (0.9, 0.09999999999999998)
# samples[key]= 0.37445867681210365
# key= (1.0, 0.0)
# samples[key]= 0.46226643726664907
# (0.8, 0.19999999999999996)
# action= [0.8, 0.19999999999999996]
# 63  Evaluations Remaining

# %%
ActionValue= {(0.0, 1.0): (10, 50), (0.1, 0.9): (10, 50), (0.2, 0.8): (10, 50), (0.30000000000000004, 0.7): (10, 50), (0.4, 0.6): (10, 50), (0.5, 0.5): (10, 50), (0.6000000000000001, 0.3999999999999999): (10, 50), (0.7000000000000001, 0.29999999999999993): (10, 50), (0.8, 0.19999999999999996): (10, 50), (0.9, 0.09999999999999998): (10, 50), (1.0, 0.0): (10, 50)}

# %%
for key in ActionValue:
    print("key=",key)
    print("self.ActionValue[key][0]=",ActionValue[key][0])
    print("self.ActionValue[key][1]=",ActionValue[key][1])
# Out:
# key= (0.0, 1.0)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.1, 0.9)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.2, 0.8)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.30000000000000004, 0.7)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.4, 0.6)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.5, 0.5)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.6000000000000001, 0.3999999999999999)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.7000000000000001, 0.29999999999999993)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.8, 0.19999999999999996)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (0.9, 0.09999999999999998)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50
# key= (1.0, 0.0)
# self.ActionValue[key][0]= 10
# self.ActionValue[key][1]= 50

# %%
class BanditRPM(object):
    def __init__(self,keys,init):
        self.ActionValue = {}
        for key in keys:
            self.ActionValue[key] = init
    
    def get_reward(self,action,text):
        print("action=",action)
        print("text=",text)
        if any(x in text for x in action):
            return 1
        else:
            return 0
    
    def choose_action(self):
        """
        Use Thompson sampling to choose action. Sample from each posterior and choose the max of the samples.
        """
        samples = {}
        for key in self.ActionValue:
            print("key=",key)
#             print("key=",self.ActionValue[key][0])
#             print("self.ActionValue[key][1]=",self.ActionValue[key][1])
            
            samples[key] = np.random.beta(self.ActionValue[key][0], self.ActionValue[key][1])
#             print("samples[key]=",samples[key])
        max_value =  max(samples, key=samples.get)
        print("max_value=",max_value)
        return max_value

    def update(self,action,reward):
        """
        Update parameters of posteriors, which are Beta distributions
        """
        print("action=",action)
        print("reward=",reward)
        a, b = self.ActionValue[action]
        a = a+reward
        b = b + 1 - reward
        a = 0.0001 if a <= 0 else a
        b = 0.0001 if b <= 0 else b
        print("a=",a)
        print("b=",b)
        self.ActionValue[action] = (a, b)

# %%
bandit = BanditRPM([('hillary','clinton'),('donald','trump'),('bernie','sanders')],(1,5))

# %%
bandit.ActionValue
# Out:
# {('hillary', 'clinton'): (1, 5),
#  ('donald', 'trump'): (1, 5),
#  ('bernie', 'sanders'): (1, 5)}

# %%
action = bandit.choose_action()
reward= bandit.get_reward(action)
bandit.update(action,reward)
# Out:
# max_value= ('hillary', 'clinton')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-18c1d55566de> in <module>
#       1 action = bandit.choose_action()
# ----> 2 reward= bandit.get_reward(action)
#       3 bandit.update(action,reward)
#
# TypeError: get_reward() missing 1 required positional argument: 'text'

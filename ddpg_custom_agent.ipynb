# %%
import matplotlib

matplotlib.use('Agg') 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from tqdm import tqdm

# %%
plt.violinplot(dataset=np.random.randn(200, 10) + np.random.randn(10))
plt.xlabel("Action")
plt.ylabel("Reward distribution")
plt.show()
plt.close()

# %%
np.random.randn(10)
# Out:
# array([-0.19640357, -1.24011496,  0.62390403,  0.84601492, -0.40865071,
#        -0.90795538,  1.67943709,  0.02216749, -0.04617523, -2.85993806])

# %%
np.random.randn(200, 10)
# Out:
# array([[ 0.06339762, -0.83954338, -0.59713954, ..., -1.29030845,
#          0.20358073,  0.87958883],
#        [ 0.99341254, -0.59055165,  2.50539792, ...,  0.84962409,
#         -0.20745646, -0.6063986 ],
#        [-0.80135717, -0.60591245,  2.28464737, ..., -0.65871756,
#          0.26615526,  0.27853503],
#        ...,
#        [-0.22724897,  0.64579319, -0.23687437, ...,  0.62240955,
#          0.54580105,  1.0243461 ],
#        [-0.29055496, -0.14969529,  0.1359772 , ..., -0.25480685,
#          1.98887242, -0.36866822],
#        [ 1.15126794,  0.22421885, -1.76119192, ..., -0.37707246,
#         -0.37546082,  0.27709492]])
